# %% [markdown]
# # ExoPie: Quickstart Guide
#
# Welcome to **ExoPie**, an open-source Python library designed for modeling and simulating the interior structures of exoplanets.
#
# This quickstart tutorial will walk you through the basics of the library, including:
# 1. Calculating Radius given Mass and composition.
# 2. Inferring the interior structure of exoplanets based on its mass and radius error.
# 3. Applying specific compositional constraints to the core and mantle.
# 4. Saving your models and visualizing the parameter space.
#
# Let's start by importing the necessary packages.

# %%
import exopie
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Calculating Radius
# get_radius is the main function used in exopie, to infer planet composition and can be used in variety of ways.
#
# For example, we can get different Mass-Radius curves for a given core-mass fractions (CMF) and plot these isocomposition lines to visialize the parameter space.

# %%
Mass,Mass_err = 5, 0.5
Radius,Radius_err = 1.6,0.05

plt.errorbar(Mass,Radius,xerr=Mass_err,yerr=Radius_err)

#plotting the isocomposition curves
M = np.linspace(0.5,18,100)
CMF = [0,0.3,0.7,1] # Core-Mass fractions to try out
xSi, xFe = 0, 0.1 # set the amount of silica in the core and iron in the mantle (molar fraction)
for cmf in CMF:
    R = exopie.get_radius(M,cmf=cmf,xSi=xSi,xFe=xFe) # finding radius given Mass and cmf
    plt.plot(M,R,label=f'CMF={cmf}')
plt.xlabel('Mass [Me]')
plt.ylabel('Radius [Re]')
plt.xlim(1,15)
plt.legend()
plt.show()

# %% [markdown]
# Assuming homogeneous mineralogy within the layers, each distinct planetary interior corresponds to a unique bulk composition. Therefore, we can apply the build-in chemical model to calculate the primary elemental mass fractions (e.g., Fe-MF, Mg-MF, etc.) for a given CMF (can also take other parameters, such as xFe, xSi, etc.)

# %%
xSi, xFe = 0, 0.1
for cmf in CMF:
    fe_mass,si_mass,mg_mass,ca_mass,al_mass,ni_mass = exopie.chemistry(cmf=cmf,xSi=xSi,xFe=xFe) # finding composition, given interior parameters
    print(f'CMF of {cmf:.1f}, gives Fe-MF {fe_mass:.2f} (Si/Fe={si_mass/fe_mass:.2f}; Mg/Fe={mg_mass/fe_mass:.2f})')
# Out:
# CMF of 0.0, gives Fe-MF 0.06 (Si/Fe=4.02; Mg/Fe=3.92)
# CMF of 0.3, gives Fe-MF 0.31 (Si/Fe=0.56; Mg/Fe=0.55)
# CMF of 0.7, gives Fe-MF 0.63 (Si/Fe=0.12; Mg/Fe=0.11)
# CMF of 1.0, gives Fe-MF 0.88 (Si/Fe=0.00; Mg/Fe=0.00)

# %% [markdown]
# ## 2. Calculating interior of an exoplanet
# First we need to initiallize the model using exopie.planet()
#
# The main parameters to take in is Mass and Radius, additional parameters include:
# * planet_type (can be 'rocky', 'water', or 'envelope')
# * xSi, xFe (for purely rocky planets)
# * CMF (for planets with volatiles)
# * Teq (for planets with volatiles)

# %%
N = 5000
Mass_arr = np.random.normal(Mass,Mass_err,N)
Radius_arr = np.random.normal(Radius,Radius_err,N)
planet = exopie.planet(Mass=Mass_arr,Radius=Radius_arr,N=N,planet_type='rocky')

# %% [markdown]
# After initializing we can run the code and find out what the results are, the output is stored in the original class
#
# Although, the initialization can also work without specifying specific planet type case and will suggest one based on physical parameters

# %%
planet = exopie.planet(Mass=Mass_arr,Radius=Radius_arr,N=N)
# Out:
# Planet is inside the rocky region, using purely rocky model.

# %%
# Running the model
planet_results = planet.run()

# %% [markdown]
# The output generated can be accessed by interacting with the result class or simply viewed using the summary table by printing the results.
#
# The important variables to look at is how many sampled points have been rejected due to physical constraints and what are the posterior distribution mean/variance.

# %%
print(planet_results)
# Out:
# Inference for rocky planet
# Accepted samples 3759 out of 5000 (75.18%)
# Param        mean  se_mean       sd     2.5%      25%      50%      75%    97.5%
# --------------------------------------------------------------------------------
# Mass         5.13     0.01     0.45     4.31     4.81     5.12     5.44     6.07
# Radius       1.58     0.00     0.04     1.49     1.55     1.58     1.61     1.66
# FeMF         0.23     0.00     0.11     0.05     0.15     0.22     0.31     0.45
# CMF          0.21     0.00     0.13     0.01     0.10     0.20     0.31     0.48
# xSi          0.10     0.00     0.06     0.01     0.05     0.10     0.15     0.19
# xFe          0.10     0.00     0.06     0.01     0.05     0.10     0.15     0.19

# %%
planet_results.FeMF # to access the individual parameter posterior
# Out:
# array([0.45872682, 0.25927125, 0.21164613, ..., 0.29014544, 0.36712246,
#        0.1320104 ], shape=(3759,))

# %% [markdown]
# ## 3. Applying specific compositional constraints to the core and mantle.
#
# We can also apply specific constraints for the interior inference model to use, specifically on the refractory ratio inside the rocky interior.
#
# For example we can use stellar values to constrain the composition and remove parameter degeneracy. For this exopie.star() need to be used to initiallize and impose constraints for planet model to use.
#
# Thus, let us assume that the Fe/Mg and Mg/Si ratios of the plaent follow the star. We thus pass these ratios as a string to the prior function to constrain possible rocky compositions

# %%
# Initialize planet parameters
planet = exopie.planet(Mass=Mass_arr,Radius=Radius_arr,N=N,planet_type='rocky')

# Stellar abundances normalized to the sun
Fe = np.random.normal(0,0.1,N)
Mg = np.random.normal(0,0.1,N)
Si = np.random.normal(0,0.1,N)
# Initialize star parameters
star = exopie.star(Fe=Fe,Mg=Mg,Si=Si,
            N=N,prior=['Fe/Mg','Mg/Si'])

# Running the model by passing the star data
planet_wstar = planet.run(host_star=star)
# Out:
# Using stellar prior to constrain rocky interior:
# Fe/Mg~𝒩(2.05, 0.27), Mg/Si~𝒩(0.79, 0.10),
# Planet is assumed to be rocky, using xSi and xFe to match the stellar abundances.

# %%
planet_wstar
# Out:
# Inference for rocky planet
# Accepted samples 3751 out of 5000 (75.02%)
# Param        mean  se_mean       sd     2.5%      25%      50%      75%    97.5%
# --------------------------------------------------------------------------------
# Mass         5.13     0.01     0.46     4.29     4.81     5.12     5.44     6.07
# Radius       1.58     0.00     0.04     1.49     1.55     1.58     1.61     1.66
# FeMF         0.33     0.00     0.02     0.29     0.32     0.33     0.35     0.38
# CMF          0.32     0.00     0.02     0.27     0.33     0.33     0.33     0.36
# xSi          0.10     0.00     0.06     0.01     0.05     0.10     0.15     0.19
# xFe          0.10     0.00     0.06     0.00     0.05     0.09     0.14     0.19

# %% [markdown]
# We can also define the prior to be a bit more complicated or adding other chemical constraints:
# - Using Ca, Al or Ni
# - Adding a functional relationship
# - Constraining the possible CMF, xSi, xFe ... boundaries

# %% [markdown]
# ## 4. Saving your models and visualizing the parameter space.

# %% [markdown]
# Now that we have results for our data, we can visuallize it them using a corner plot ([corner.py](https://corner.readthedocs.io/en/latest/))

# %%
import corner

# %%
fig = None
# first plot the unconstrained rocky interior
chains,labels = planet_results.get_outputs(parameters=['Mass','Radius','FeMF'])
fig = corner.corner(chains,fig=fig,labels=labels,color='k',
                    smooth=True,hist_kwargs = {'density':True});
# next plot the constrained interior that uses stellar Fe/Mg as prior
chains,labels = planet_wstar.get_outputs(parameters=['Mass','Radius','FeMF'])
fig = corner.corner(chains,fig=fig,labels=labels,color='r',
                    smooth=True,hist_kwargs = {'density':True});

# %% [markdown]
# We can see that Utilizing stellar refractory ratio prior places vital constraints on a planet's interior parameters. While less critical for purely rocky planets, this prior is essential when modeling volatile-rich planets containing H2 or H2O layers due to a fundamental degeneracy in the parameter space. When only a planet's Mass and Radius (M-R) are known, a volatile-rich planet presents two major unknowns: water/atmospheric-mass Fraction (WMF/AMF) and core-mass Fraction (CMF). Consequently, there is no unique compositional solution for a given M-R pair, as an increase in core density can be perfectly offset by a thicker volatile envelope. By applying a stellar prior (even one with high uncertainty) we effectively constrain the rocky iron-mass fraction (Fe-MF). This breaks the degeneracy and allows us to accurately capture the WMF/AMF.
